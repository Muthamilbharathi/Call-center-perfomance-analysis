# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime as dt
import seaborn as sns 
import streamlit as st

# %%
call=pd.read_excel(r"C:\Users\ELCOT\OneDrive\New Folder\Call center perfomance analysis\Dataset\call_center.xlsx",header=2,usecols="B:H",)

# %%
call.head()
# Out:
#   Call number Customer ID  Duration Representative Date of Call  \
# 0   Call_7271       C0003       NaN            R05   2023-01-01
# 1   Call_7272       C0004     119.0            R05   2023-01-01
# 2   Call_7273       C0005      68.0            R02   2023-01-01
# 3   Call_7274       C0014     119.0            R02   2023-01-01
# 4   Call_7275       C0011       NaN            R01   2023-01-02
#
#    Purchase Amount  Satisfaction Rating
# 0            128.0                  4.9
# 1            135.0                  2.9
# 2             66.0                  4.7
# 3              NaN                  2.9
# 4             31.0                  2.8

# %%
customers=pd.read_excel(r"C:\Users\ELCOT\OneDrive\New Folder\Call center perfomance analysis\Dataset\call_center.xlsx",header=2,usecols="L:O",nrows=15)

# %%
customers
# Out:
#    Customer ID.1  Gedner  Age        City
# 0          C0001    Male   41    Columbus
# 1          C0002    Male   31   Cleveland
# 2          C0003    Male   26  Cincinnati
# 3          C0004    Male   36  Cincinnati
# 4          C0005    Male   37    Columbus
# 5          C0006    Male   23    Columbus
# 6          C0007  Female   22   Cleveland
# 7          C0008  Female   42   Cleveland
# 8          C0009  Female   25    Columbus
# 9          C0010  Female   30   Cleveland
# 10         C0011  Female   30  Cincinnati
# 11         C0012  Female   28  Cincinnati
# 12         C0013  Female   37   Cleveland
# 13         C0014  Female   38    Columbus
# 14         C0015  Female   43   Cleveland

# %%
customers.head()
# Out:
#   Customer ID.1 Gedner  Age        City
# 0         C0001   Male   41    Columbus
# 1         C0002   Male   31   Cleveland
# 2         C0003   Male   26  Cincinnati
# 3         C0004   Male   36  Cincinnati
# 4         C0005   Male   37    Columbus

# %%
call.tail()
# Out:
#     Call number Customer ID  Duration Representative Date of Call  \
# 995   Call_8266       C0002      81.0            R05   2023-12-30
# 996   Call_8267       C0007     127.0            R04   2023-12-30
# 997   Call_8268       C0013     146.0            R05   2023-12-31
# 998   Call_8269       C0010     123.0            R05   2023-12-31
# 999   Call_8270       C0009     114.0            R01   2023-12-31
#
#      Purchase Amount  Satisfaction Rating
# 995             28.0                  3.9
# 996            215.0                  3.8
# 997            115.0                  2.3
# 998             64.0                  3.7
# 999             40.0                  3.9

# %%
call.sample(4)
# Out:
#     Call number Customer ID  Duration Representative Date of Call  \
# 854   Call_8125       C0014      94.0            R03   2023-10-19
# 69    Call_7340       C0006     141.0            R03   2023-01-27
# 586   Call_7857       C0002      90.0            R05   2023-07-01
# 272   Call_7543       C0009     149.0            R05   2023-03-25
#
#      Purchase Amount  Satisfaction Rating
# 854            120.0                  3.5
# 69              54.0                  0.0
# 586            129.0                  3.9
# 272             60.0                  3.9

# %%
type(call)
type(customers)
# Out:
# pandas.DataFrame

# %%
call.shape
# Out:
# (1000, 7)

# %%
customers.shape
# Out:
# (15, 4)

# %%
call.columns
# Out:
# Index(['Call number', 'Customer ID', 'Duration', 'Representative',
#        'Date of Call', 'Purchase Amount', 'Satisfaction Rating'],
#       dtype='str')

# %%
call.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Call number          1000 non-null   str
#  1   Customer ID          1000 non-null   str
#  2   Duration             998 non-null    float64
#  3   Representative       1000 non-null   str
#  4   Date of Call         1000 non-null   datetime64[us]
#  5   Purchase Amount      997 non-null    float64
#  6   Satisfaction Rating  995 non-null    float64
# dtypes: datetime64[us](1), float64(3), str(3)
# memory usage: 54.8 KB

# %%
call.describe()
# Out:
#          Duration                Date of Call  Purchase Amount  \
# count  998.000000                        1000       997.000000
# mean    89.785571  2023-06-15 00:34:33.600000        96.755266
# min      2.000000         2023-01-01 00:00:00        20.000000
# 25%     62.000000         2023-03-20 00:00:00        52.000000
# 50%     89.000000         2023-05-25 12:00:00        88.000000
# 75%    118.750000         2023-09-24 00:00:00       130.000000
# max    176.000000         2023-12-31 00:00:00       225.000000
# std     37.635907                         NaN        52.445059
#
#        Satisfaction Rating
# count           995.000000
# mean              3.883920
# min               0.000000
# 25%               3.400000
# 50%               4.000000
# 75%               4.500000
# max               5.000000
# std               0.836469

# %% [markdown]
# 1.total call
# 2.peak month
# 3.best representative
# 4.average duration of call
# 5.purchase amount
# 6.busy day
# 7.customer gender,city wise,,age wise

# %%
call.isnull()
# Out:
#      Call number  Customer ID  Duration  Representative  Date of Call  \
# 0          False        False      True           False         False
# 1          False        False     False           False         False
# 2          False        False     False           False         False
# 3          False        False     False           False         False
# 4          False        False      True           False         False
# ..           ...          ...       ...             ...           ...
# 995        False        False     False           False         False
# 996        False        False     False           False         False
# 997        False        False     False           False         False
# 998        False        False     False           False         False
# 999        False        False     False           False         False
#
#      Purchase Amount  Satisfaction Rating
# 0              False                False
# ...

# %%
call.isnull().sum()
# Out:
# Call number            0
# Customer ID            0
# Duration               2
# Representative         0
# Date of Call           0
# Purchase Amount        3
# Satisfaction Rating    5
# dtype: int64

# %%
customers.isnull().sum()
# Out:
# Customer ID.1    0
# Gedner           0
# Age              0
# City             0
# dtype: int64

# %%
call.isnull().any()  #any denotes any null in the column
# Out:
# Call number            False
# Customer ID            False
# Duration                True
# Representative         False
# Date of Call           False
# Purchase Amount         True
# Satisfaction Rating     True
# dtype: bool

# %%
call.isnull().any(axis=0)  #axis = o is the column
# Out:
# Call number            False
# Customer ID            False
# Duration                True
# Representative         False
# Date of Call           False
# Purchase Amount         True
# Satisfaction Rating     True
# dtype: bool

# %%
call.isnull().any(axis=1) #axis =1 denotes row
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
call.isnull().all() #all denotes entire column
# Out:
# Call number            False
# Customer ID            False
# Duration               False
# Representative         False
# Date of Call           False
# Purchase Amount        False
# Satisfaction Rating    False
# dtype: bool

# %%
call[call.isnull().any(axis=1)]
# Out:
#    Call number Customer ID  Duration Representative Date of Call  \
# 0    Call_7271       C0003       NaN            R05   2023-01-01
# 3    Call_7274       C0014     119.0            R02   2023-01-01
# 4    Call_7275       C0011       NaN            R01   2023-01-02
# 12   Call_7283       C0002      98.0            R02   2023-01-04
# 17   Call_7288       C0009      28.0            R03   2023-01-05
# 24   Call_7295       C0010      54.0            R01   2023-01-08
# 29   Call_7300       C0015     155.0            R01   2023-01-10
# 46   Call_7317       C0014     131.0            R01   2023-01-19
# 51   Call_7322       C0013     100.0            R04   2023-01-21
# 54   Call_7325       C0013      59.0            R05   2023-01-22
#
#     Purchase Amount  Satisfaction Rating
# 0             128.0                  4.9
# 3               NaN                  2.9
# 4              31.0                  2.8
# 12              NaN                  3.5
# 17              NaN                  3.8
# ...

# %%
call["Purchase Amount"].fillna(call["Purchase Amount"].mean(),inplace=True)
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_1528\65082465.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   call["Purchase Amount"].fillna(call["Purchase Amount"].mean(),inplace=True)
# 0      128.000000
# 1      135.000000
# 2       66.000000
# 3       96.755266
# 4       31.000000
#           ...
# 995     28.000000
# ...

# %%
call['Representative']=call['Representative'].fillna("unknown",inplace=True)
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_1528\856888587.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   call['Representative']=call['Representative'].fillna("unknown",inplace=True)

# %%
call.duplicated().sum()
# Out:
# np.int64(0)

# %%
call.drop_duplicates().all(axis=1)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Length: 1000, dtype: bool

# %%
call.drop_duplicates().all(axis=1).sum()
# Out:
# np.int64(999)

# %%
call.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Call number          1000 non-null   str
#  1   Customer ID          1000 non-null   str
#  2   Duration             998 non-null    float64
#  3   Representative       1000 non-null   str
#  4   Date of Call         1000 non-null   datetime64[us]
#  5   Purchase Amount      997 non-null    float64
#  6   Satisfaction Rating  995 non-null    float64
# dtypes: datetime64[us](1), float64(3), str(3)
# memory usage: 54.8 KB

# %%
call.drop_duplicates(inplace=True)

# %%
call['Date of Call']=pd.to_datetime(call['Date of Call'])

# %%
call.dtypes
# Out:
# Call number                       str
# Customer ID                       str
# Duration                      float64
# Representative                    str
# Date of Call           datetime64[us]
# Purchase Amount               float64
# Satisfaction Rating           float64
# dtype: object

# %%
call.rename(columns={'Purchase Amount':"Amount","Satisfaction Rating":"Rating"},inplace=True)

# %%
call.to_csv("Cleaned_data1.csv",index=False)

# %%
call[['Amount','Representative','Duration','Rating']]
# Out:
#      Amount Representative  Duration  Rating
# 0     128.0            R05       NaN     4.9
# 1     135.0            R05     119.0     2.9
# 2      66.0            R02      68.0     4.7
# 3       NaN            R02     119.0     2.9
# 4      31.0            R01       NaN     2.8
# ..      ...            ...       ...     ...
# 995    28.0            R05      81.0     3.9
# 996   215.0            R04     127.0     3.8
# 997   115.0            R05     146.0     2.3
# 998    64.0            R05     123.0     3.7
# 999    40.0            R01     114.0     3.9
#
# [1000 rows x 4 columns]

# %%
type(call['Customer ID'])
# Out:
# pandas.Series

# %%
call.Rating.sort_values(ascending=False)
# Out:
# 20     5.0
# 39     5.0
# 337    5.0
# 921    5.0
# 940    5.0
#       ...
# 24     NaN
# 29     NaN
# 46     NaN
# 51     NaN
# 54     NaN
# Name: Rating, Length: 1000, dtype: float64

# %%
call.Representative.unique()
# Out:
# <StringArray>
# ['R05', 'R02', 'R01', 'R04', 'R03']
# Length: 5, dtype: str

# %%
customers.City.unique()
# Out:
# <StringArray>
# ['Columbus', 'Cleveland', 'Cincinnati']
# Length: 3, dtype: str

# %%
repcount=call.Representative.value_counts()
repcount.max()
# Out:
# np.int64(218)

# %%
rep_count=call.groupby('Representative')['Rating'].mean()
print(rep_count)
# Out:
# Representative
# R01    3.918817
# R02    3.870642
# R03    3.858937
# R04    3.897838
# R05    3.878894
# Name: Rating, dtype: float64

# %%
high=call.groupby('Representative')['Call number'].count()
high.max()
# Out:
# np.int64(218)

# %%
merge_table=pd.merge(call,customers,left_on='Customer ID',right_on='Customer ID.1')
print(merge_table)
# Out:
#     Call number Customer ID  Duration Representative Date of Call  Amount  \
# 0     Call_7271       C0003       NaN            R05   2023-01-01   128.0
# 1     Call_7272       C0004     119.0            R05   2023-01-01   135.0
# 2     Call_7273       C0005      68.0            R02   2023-01-01    66.0
# 3     Call_7274       C0014     119.0            R02   2023-01-01     NaN
# 4     Call_7275       C0011       NaN            R01   2023-01-02    31.0
# ..          ...         ...       ...            ...          ...     ...
# 995   Call_8266       C0002      81.0            R05   2023-12-30    28.0
# 996   Call_8267       C0007     127.0            R04   2023-12-30   215.0
# 997   Call_8268       C0013     146.0            R05   2023-12-31   115.0
# 998   Call_8269       C0010     123.0            R05   2023-12-31    64.0
# 999   Call_8270       C0009     114.0            R01   2023-12-31    40.0
#
#      Rating Customer ID.1  Gedner  Age        City
# ...

# %%
call.shape
# Out:
# (1000, 7)

# %%
call.dtypes
customers.dtypes
# Out:
# Customer ID.1      str
# Gedner             str
# Age              int64
# City               str
# dtype: object

# %%
merge_table.groupby("City")["Amount"].sum()
# Out:
# City
# Cincinnati    26061.0
# Cleveland     37741.0
# Columbus      32663.0
# Name: Amount, dtype: float64

# %% [markdown]
# How many calls were received?
# Which representative handled the most calls?
# Which representative generated the highest purchase amount?
# Which city generated the highest revenue?
# What is the average customer satisfaction by representative?
# Which customers made purchases above the average amount?
# Which representatives need improvement based on satisfaction scores?

# %%
call['Call number'].count()
# Out:
# np.int64(1000)

# %%
(call.groupby("Representative").count())
# Out:
#                 Call number  Customer ID  Duration  Date of Call  Amount  \
# Representative
# R01                     189          189       188           189     189
# R02                     218          218       218           218     216
# R03                     207          207       207           207     206
# R04                     186          186       186           186     186
# R05                     200          200       199           200     200
#
#                 Rating
# Representative
# R01                186
# R02                218
# R03                207
# R04                185
# R05                199

# %%
call.describe(include='all')
# Out:
#        Call number Customer ID    Duration Representative  \
# count         1000        1000  998.000000           1000
# unique        1000          15         NaN              5
# top      Call_7271       C0004         NaN            R02
# freq             1          82         NaN            218
# mean           NaN         NaN   89.785571            NaN
# min            NaN         NaN    2.000000            NaN
# 25%            NaN         NaN   62.000000            NaN
# 50%            NaN         NaN   89.000000            NaN
# 75%            NaN         NaN  118.750000            NaN
# max            NaN         NaN  176.000000            NaN
# std            NaN         NaN   37.635907            NaN
#
#                       Date of Call      Amount      Rating
# count                         1000  997.000000  995.000000
# unique                         NaN         NaN         NaN
# top                            NaN         NaN         NaN
# ...

# %% [markdown]
# Average Purchase

# %%
avrgamnt=call['Amount'].mean()
print(avrgamnt)
# Out:
# 96.75526579739217

# %% [markdown]
# Average satisfaction

# %%
avrgsts=call['Rating'].mean()
print(avrgsts)
# Out:
# 3.8839195979899497

# %% [markdown]
# Total customers
# Avg purchase
# Avg satisfaction
# Avg Duration
# Total Purchase amount
# Total call

# %%
cust=call['Call number'].count()
print(cust)
# Out:
# 1000

# %%
avrgamnt=call['Amount'].mean()
print(avrgamnt)
# Out:
# 96.75526579739217

# %%
avrgsts=call['Rating'].mean()
print(avrgsts)
# Out:
# 3.8839195979899497

# %%
avrgdur=call['Duration'].mean()
print(avrgdur)
# Out:
# 89.78557114228457

# %%
tlamnt=call['Amount'].sum()
print(tlamnt)
# Out:
# 96465.0

# %%
tlcall=call['Call number'].count()
print(tlcall)
# Out:
# 1000

# %%
call['Date of Call'].dtype
# Out:
# dtype('<M8[us]')

# %%
call['Month']=call['Date of Call'].dt.month_name()

# %%
call.head()
# Out:
#   Call number Customer ID  Duration Representative Date of Call  Amount  \
# 0   Call_7271       C0003       NaN            R05   2023-01-01   128.0
# 1   Call_7272       C0004     119.0            R05   2023-01-01   135.0
# 2   Call_7273       C0005      68.0            R02   2023-01-01    66.0
# 3   Call_7274       C0014     119.0            R02   2023-01-01     NaN
# 4   Call_7275       C0011       NaN            R01   2023-01-02    31.0
#
#    Rating    Month
# 0     4.9  January
# 1     2.9  January
# 2     4.7  January
# 3     2.9  January
# 4     2.8  January

# %% [markdown]
# how busy each month ?

# %%
monthcl=(call.groupby("Month")['Call number'].count())
print(monthcl)
# Out:
# Month
# April        136
# August        50
# December      53
# February      66
# January       79
# July          64
# June          67
# March        155
# May           83
# November      57
# October      114
# September     76
# Name: Call number, dtype: int64

# %%
monthcl.plot(kind='line',marker='*')
plt.ylabel('Number of call')
plt.title('Monthly call Volume')
plt.show()

# %% [markdown]
# which representative handle the most call

# %%
repcl=call.groupby('Representative')['Call number'].count()
print(repcl)
# Out:
# Representative
# R01    189
# R02    218
# R03    207
# R04    186
# R05    200
# Name: Call number, dtype: int64

# %%
repcl.plot(kind='bar')
plt.ylabel('count')
plt.title('call handled')
# Out:
# Text(0.5, 1.0, 'call handled')

# %% [markdown]
# are most customer satisfied?

# %%
call['Rating']=call['Rating'].round()

# %%
custs=call.Rating.value_counts().sort_index()
print(custs)
# Out:
# Rating
# 0.0      1
# 1.0      8
# 2.0     66
# 3.0    189
# 4.0    485
# 5.0    246
# Name: count, dtype: int64

# %%
custs.plot(kind='pie',autopct="%1.1f%%")
plt.xlabel("Satisfaction ")
# Out:
# Text(0.5, 0, 'Satisfaction ')

# %% [markdown]
# call duration vs purchase amount

# %%
plt.scatter(call['Duration'],call['Amount'])
plt.xlabel('Call Duration')
plt.ylabel('Purchase Amount')
plt.title('Call Duration vs Purchase Amount')
plt.show()

# %%
numeric=call.select_dtypes(include='number')
print(numeric)
# Out:
#      Duration  Amount  Rating
# 0         NaN   128.0     5.0
# 1       119.0   135.0     3.0
# 2        68.0    66.0     5.0
# 3       119.0     NaN     3.0
# 4         NaN    31.0     3.0
# ..        ...     ...     ...
# 995      81.0    28.0     4.0
# 996     127.0   215.0     4.0
# 997     146.0   115.0     2.0
# 998     123.0    64.0     4.0
# 999     114.0    40.0     4.0
#
# [1000 rows x 3 columns]

# %%
import seaborn as sns #for chart

# %%
numeric.corr()
# Out:
#           Duration    Amount    Rating
# Duration  1.000000 -0.013106 -0.016781
# Amount   -0.013106  1.000000 -0.012523
# Rating   -0.016781 -0.012523  1.000000

# %%
sns.heatmap(numeric.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
st.title('call center performance dashboard')
# Out:
# 2026-06-30 15:08:33.719 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-30 15:08:34.281
# ...
#   command:
#
#     streamlit run C:\Users\ELCOT\AppData\Roaming\Python\Python314\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-06-30 15:08:34.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-30 15:08:34.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
